# %%
import pandas as pd
import numpy as np

# %%
shark = pd.read_excel('GSAF5.xls')
shark
# Out:
#         Case Number         Date    Year        Type Country  \
# 0      2022.07.03.a  03-Jul-2022  2022.0  Unprovoked     USA
# 1      2022.07.01.b  01-Jul-2022  2022.0  Unprovoked   EGYPT
# 2      2022.07.01.a  01-Jul-2022  2022.0  Unprovoked   EGYPT
# 3      2022.06.30.b  30-Jun-2022  2022.0  Unprovoked     USA
# 4      2022.06.30.a  30-Jun-2022  2022.0  Unprovoked     USA
# ...             ...          ...     ...         ...     ...
# 25828           NaN          NaN     NaN         NaN     NaN
# 25829           NaN          NaN     NaN         NaN     NaN
# 25830           NaN          NaN     NaN         NaN     NaN
# 25831           NaN          NaN     NaN         NaN     NaN
# 25832            xx          NaN     NaN         NaN     NaN
#
#                                 Area                           Location  \
# 0                           New York  Smith Point Beach, Suffolk County
# 1      Hurghada, Red Sea Governorate                      Sahl Hasheesh
# ...

# %%
shark.shape
# Out:
# (25833, 24)

# %%
shark.describe()
# Out:
#               Year  original order
# count  6772.000000     6774.000000
# mean   1932.323243     3388.496900
# std     275.933296     1955.625246
# min       0.000000        2.000000
# 25%    1945.000000     1695.250000
# 50%    1983.000000     3388.500000
# 75%    2008.000000     5081.750000
# max    2022.000000     6774.000000

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25833 entries, 0 to 25832
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8811 non-null   object
#  1   Date                    6774 non-null   object
#  2   Year                    6772 non-null   float64
#  3   Type                    6755 non-null   object
#  4   Country                 6724 non-null   object
#  5   Area                    6299 non-null   object
#  6   Location                6216 non-null   object
#  7   Activity                6197 non-null   object
#  8   Name                    6557 non-null   object
#  9   Sex                     6198 non-null   object
#  10  Age                     3818 non-null   object
#  11  Injury                  6740 non-null   object
#  12  Fatal (Y/N)             6218 non-null   object
#  13  Time                    3292 non-null   object
# ...

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Remover colunas que não irei utilizar
shark_df = shark.drop(['Case Number', 'Type', 'Location', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23'], axis = 1)

# %%
shark_df.shape
# Out:
# (25833, 12)

# %%
shark_df.head()
# Out:
#           Date    Year Country                           Area  \
# 0  03-Jul-2022  2022.0     USA                       New York
# 1  01-Jul-2022  2022.0   EGYPT  Hurghada, Red Sea Governorate
# 2  01-Jul-2022  2022.0   EGYPT  Hurghada, Red Sea Governorate
# 3  30-Jun-2022  2022.0     USA                       New York
# 4  30-Jun-2022  2022.0     USA                        Florida
#
#               Activity             Name Sex   Age  \
# 0  Lifeguard Exercises       Zach Gallo    M  NaN
# 1             Swimming  Romanian female    F  40s
# 2             Swimming  Elisabeth Sauer    F   68
# 3             Swimming             male    M  NaN
# 4           Scalloping   Addison Bethea    F   17
#
#                              Injury Fatal (Y/N)   Time  \
# 0  Injuries to chest and right hand           N  10h15
# 1                             FATAL           Y    NaN
# 2                             FATAL           Y    NaN
# 3              Injury to right foot           N  13h00
# ...

# %%
shark_df = shark_df['Country'].str.lower()

# %%
shark_df = shark_df['Country'].str.lower()
shark_df = shark_df['Injury'].str.lower()
shark_df = shark_df['Area'].str.lower()
shark_df = shark_df['Activity'].str.lower()
shark_df = shark_df['Name'].str.lower()
shark_df = shark_df['Injury'].str.lower()
shark_df = shark_df['Fatal (Y/N)'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [205], in <cell line: 1>()
# ----> 1 shark_df = shark_df['Country'].str.lower()
#       2 shark_df = shark_df['Injury'].str.lower()
#       3 shark_df = shark_df['Area'].str.lower()
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
shark_df = shark_df[shark_df['Country','Area', 'Sex', 'Activity', 'Injury', 'Fatal (Y/N)'].str.lower(), axis=0]
# Out:
#   Input In [179]
#     shark_df = shark_df[shark_df['Country','Area', 'Sex', 'Activity', 'Injury', 'Fatal (Y/N)'].str.lower(), axis=0]
#                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
shark['Fatal (Y/N)'].isnull().sum()
# Out:
# 19615

# %%
shark_fatal = shark[shark['Injury'] == 'FATAL']
shark_fatal.head()
# Out:
#      Case Number         Date    Year        Type       Country  \
# 1   2022.07.01.b  01-Jul-2022  2022.0  Unprovoked         EGYPT
# 2   2022.07.01.a  01-Jul-2022  2022.0  Unprovoked         EGYPT
# 7     2022.06.28  28-Jun-2022  2022.0  Unprovoked  SOUTH AFRICA
# 29    2022.03.18  18-Mar-2022  2022.0  Unprovoked      COLUMBIA
# 38    2022.02.16  16-Feb-2022  2022.0  Unprovoked     AUSTRALIA
#
#                              Area                          Location  Activity  \
# 1   Hurghada, Red Sea Governorate                     Sahl Hasheesh  Swimming
# 2   Hurghada, Red Sea Governorate                     Sahl Hasheesh  Swimming
# 7           Western Cape Province  Sanctuary Beach, Plettenberg Bay  Swimming
# 29             Isla De San Andres                      La Piscinita  Swimming
# 38                New South Wales              Buchan Point, Sydney  Swimming
#
#                     Name Sex   ...     Species   \
# 1        Romanian female    F  ...          NaN
# ...

# %%
shark_fatal = shark[shark['Fatal (Y/N)'].str.lower() == 'y']
shark_fatal.head()
# Out:
#      Case Number         Date    Year        Type       Country  \
# 1   2022.07.01.b  01-Jul-2022  2022.0  Unprovoked         EGYPT
# 2   2022.07.01.a  01-Jul-2022  2022.0  Unprovoked         EGYPT
# 7     2022.06.28  28-Jun-2022  2022.0  Unprovoked  SOUTH AFRICA
# 29    2022.03.18  18-Mar-2022  2022.0  Unprovoked      COLUMBIA
# 38    2022.02.16  16-Feb-2022  2022.0  Unprovoked     AUSTRALIA
#
#                              Area                          Location  Activity  \
# 1   Hurghada, Red Sea Governorate                     Sahl Hasheesh  Swimming
# 2   Hurghada, Red Sea Governorate                     Sahl Hasheesh  Swimming
# 7           Western Cape Province  Sanctuary Beach, Plettenberg Bay  Swimming
# 29             Isla De San Andres                      La Piscinita  Swimming
# 38                New South Wales              Buchan Point, Sydney  Swimming
#
#                     Name Sex   ...     Species   \
# 1        Romanian female    F  ...          NaN
# ...

# %%
shark['Country'].isnull().sum()
# Out:
# 19109

# %%
shark_country = shark['Country'].str.lower()

# %%
shark['Activity'].isnull().sum()
# Out:
# 19636

# %%
shark_activity = shark['Activity'].str.lower()
